# %%
# Install all relevant packages
# !pip install transformers
# !pip install torch
# !pip install pip install mendelai-brat-parser
# !pip install smart-open
# !pip install -U scikit-learn
# Out:
# Collecting transformers
#   Downloading transformers-4.38.1-py3-none-any.whl.metadata (131 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.1/131.1 kB 2.0 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: filelock in /lustre/home/almusawiaf/anaconda3/envs/envGNN/lib/python3.8/site-packages (from transformers) (3.13.1)
# Collecting huggingface-hub<1.0,>=0.19.3 (from transformers)
#   Downloading huggingface_hub-0.21.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy>=1.17 in /lustre/home/almusawiaf/anaconda3/envs/envGNN/lib/python3.8/site-packages (from transformers) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in /lustre/home/almusawiaf/anaconda3/envs/envGNN/lib/python3.8/site-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /lustre/home/almusawiaf/anaconda3/envs/envGNN/lib/python3.8/site-packages (from transformers) (6.0.1)
# Collecting regex!=2019.12.17 (from transformers)
#   Downloading regex-2023.12.25-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 kB 722.6 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: requests in /lustre/home/almusawiaf/anaconda3/envs/envGNN/lib/python3.8/site-packages (from transformers) (2.31.0)
# Collecting tokenizers<0.19,>=0.14 (from transformers)
#   Downloading tokenizers-0.15.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Collecting safetensors>=0.4.1 (from transformers)
#   Downloading safetensors-0.4.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Requirement already satisfied: tqdm>=4.27 in /lustre/home/almusawiaf/anaconda3/envs/envGNN/lib/python3.8/site-packages (from transformers) (4.66.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /lustre/home/almusawiaf/anaconda3/envs/envGNN/lib/python3.8/site-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (2024.2.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /lustre/home/almusawiaf/anaconda3/envs/envGNN/lib/python3.8/site-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /lustre/home/almusawiaf/anaconda3/envs/envGNN/lib/python3.8/site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /lustre/home/almusawiaf/anaconda3/envs/envGNN/lib/python3.8/site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /lustre/home/almusawiaf/anaconda3/envs/envGNN/lib/python3.8/site-packages (from requests->transformers) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /lustre/home/almusawiaf/anaconda3/envs/envGNN/lib/python3.8/site-packages (from requests->transformers) (2024.2.2)
# Downloading transformers-4.38.1-py3-none-any.whl (8.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.5/8.5 MB 33.3 MB/s eta 0:00:0000:0100:01
# Downloading huggingface_hub-0.21.1-py3-none-any.whl (346 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 346.1/346.1 kB 7.3 MB/s eta 0:00:00:00:01
# Downloading regex-2023.12.25-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (777 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 777.0/777.0 kB 17.5 MB/s eta 0:00:0000:01
# Downloading safetensors-0.4.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 17.2 MB/s eta 0:00:00:00:01
# Downloading tokenizers-0.15.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 38.1 MB/s eta 0:00:00:00:01
# Installing collected packages: safetensors, regex, huggingface-hub, tokenizers, transformers
# Successfully installed huggingface-hub-0.21.1 regex-2023.12.25 safetensors-0.4.2 tokenizers-0.15.2 transformers-4.38.1
# Requirement already satisfied: torch in /lustre/home/almusawiaf/anaconda3/envs/envGNN/lib/python3.8/site-packages (2.2.0)
# Requirement already satisfied: filelock in /lustre/home/almusawiaf/anaconda3/envs/envGNN/lib/python3.8/site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /lustre/home/almusawiaf/anaconda3/envs/envGNN/lib/python3.8/site-packages (from torch) (4.9.0)
# Requirement already satisfied: sympy in /lustre/home/almusawiaf/anaconda3/envs/envGNN/lib/python3.8/site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /lustre/home/almusawiaf/anaconda3/envs/envGNN/lib/python3.8/site-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in /lustre/home/almusawiaf/anaconda3/envs/envGNN/lib/python3.8/site-packages (from torch) (3.1.3)
# Requirement already satisfied: fsspec in /lustre/home/almusawiaf/anaconda3/envs/envGNN/lib/python3.8/site-packages (from torch) (2024.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /lustre/home/almusawiaf/anaconda3/envs/envGNN/lib/python3.8/site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /lustre/home/almusawiaf/anaconda3/envs/envGNN/lib/python3.8/site-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: pip in /lustre/home/almusawiaf/anaconda3/envs/envGNN/lib/python3.8/site-packages (23.3.1)
# Collecting install
#   Downloading install-1.3.5-py3-none-any.whl.metadata (925 bytes)
# Collecting mendelai-brat-parser
#   Downloading mendelai_brat_parser-0.0.11.tar.gz (4.6 kB)
#   Preparing metadata (setup.py) ... done
# Downloading install-1.3.5-py3-none-any.whl (3.2 kB)
# Building wheels for collected packages: mendelai-brat-parser
#   Building wheel for mendelai-brat-parser (setup.py) ... done
#   Created wheel for mendelai-brat-parser: filename=mendelai_brat_parser-0.0.11-py3-none-any.whl size=4921 sha256=04882369c85d632665926a8e7a58a01bba59de4549f897371ca7b45f663b22be
#   Stored in directory: /lustre/home/almusawiaf/.cache/pip/wheels/90/a7/ff/138853d8196095fec56e0a97779a96d754b98f169c063beca3
# Successfully built mendelai-brat-parser
# Installing collected packages: mendelai-brat-parser, install
# Successfully installed install-1.3.5 mendelai-brat-parser-0.0.11
# Collecting smart-open
#   Downloading smart_open-7.0.1-py3-none-any.whl.metadata (23 kB)
# Collecting wrapt (from smart-open)
#   Downloading wrapt-1.16.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Downloading smart_open-7.0.1-py3-none-any.whl (60 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 1.1 MB/s eta 0:00:00ta 0:00:01
# Downloading wrapt-1.16.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (83 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.4/83.4 kB 1.4 MB/s eta 0:00:00:00:01
# Installing collected packages: wrapt, smart-open
# Successfully installed smart-open-7.0.1 wrapt-1.16.0
# Requirement already satisfied: scikit-learn in /lustre/home/almusawiaf/anaconda3/envs/envGNN/lib/python3.8/site-packages (1.3.2)
# Requirement already satisfied: numpy<2.0,>=1.17.3 in /lustre/home/almusawiaf/anaconda3/envs/envGNN/lib/python3.8/site-packages (from scikit-learn) (1.24.3)
# Requirement already satisfied: scipy>=1.5.0 in /lustre/home/almusawiaf/anaconda3/envs/envGNN/lib/python3.8/site-packages (from scikit-learn) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in /lustre/home/almusawiaf/anaconda3/envs/envGNN/lib/python3.8/site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /lustre/home/almusawiaf/anaconda3/envs/envGNN/lib/python3.8/site-packages (from scikit-learn) (3.3.0)

# %%
# Import libraries
import transformers
import torch
import torch.nn as nn
import itertools

from transformers import BertTokenizer, BertForTokenClassification, BertModel
from transformers import pipeline
from transformers import AutoTokenizer, AutoModelForTokenClassification
from transformers import BertTokenizerFast,  BatchEncoding
from tokenizers import Encoding
from transformers import AutoTokenizer, AutoModel


from brat_parser import get_entities_relations_attributes_groups
import zipfile
import os

from dataclasses import dataclass
from torch.utils.data import Dataset
from transformers import PreTrainedTokenizerFast
from dataclasses import dataclass
from typing import List
from torch.utils.data.dataloader import DataLoader
from transformers import BertForTokenClassification, AdamW
from torch.nn import functional as F
from sklearn.metrics import f1_score
import numpy as np
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix, ConfusionMatrixDisplay
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /lustre/home/almusawiaf/PhD_Projects/HGNN_Project/Notes_Embedding/b_Embedding_Extraction/clinical_note_embeddings.ipynb Cell 2 line 2
#       <a href='vscode-notebook-cell://athena3.hprc.vcu.edu/lustre/home/almusawiaf/PhD_Projects/HGNN_Project/Notes_Embedding/b_Embedding_Extraction/clinical_note_embeddings.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> # Import libraries
# ----> <a href='vscode-notebook-cell://athena3.hprc.vcu.edu/lustre/home/almusawiaf/PhD_Projects/HGNN_Project/Notes_Embedding/b_Embedding_Extraction/clinical_note_embeddings.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> import transformers
#       <a href='vscode-notebook-cell://athena3.hprc.vcu.edu/lustre/home/almusawiaf/PhD_Projects/HGNN_Project/Notes_Embedding/b_Embedding_Extraction/clinical_note_embeddings.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> import torch
#       <a href='vscode-notebook-cell://athena3.hprc.vcu.edu/lustre/home/almusawiaf/PhD_Projects/HGNN_Project/Notes_Embedding/b_Embedding_Extraction/clinical_note_embeddings.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> import torch.nn as nn
#
# ModuleNotFoundError: No module named 'transformers'

# %%
# Read in clinical notes file
import pandas as pd
clinical_notes = pd.read_csv("../Data/MIMIC_resources/MODIFIED_NOTEEVENTS_2083180.csv")
clinical_notes.head(5)

# %%
# Text column is the section of interest
# Creating a subsampled dataframe as an example with the first 1000 notes

subsampled_notes_df = clinical_notes.head(10)
print(subsampled_notes_df.columns)

clin_notes = subsampled_notes_df['TEXT'].tolist()
# Out:
# Index(['ROW_ID', 'SUBJECT_ID', 'HADM_ID', 'CHARTDATE', 'CHARTTIME',
#        'STORETIME', 'CATEGORY', 'DESCRIPTION', 'CGID', 'ISERROR', 'TEXT'],
#       dtype='object')

# %%
clin_notes[0]
# Out:
# 'Admission Date:  [**2151-7-16**]       Discharge Date:  [**2151-8-4**]\n\n\nService:\nADDENDUM:\n\nRADIOLOGIC STUDIES:  Radiologic studies also included a chest\nCT, which confirmed cavitary lesions in the left lung apex\nconsistent with infectious process/tuberculosis.  This also\nmoderate-sized left pleural effusion.\n\nHEAD CT:  Head CT showed no intracranial hemorrhage or mass\neffect, but old infarction consistent with past medical\nhistory.\n\nABDOMINAL CT:  Abdominal CT showed lesions of\nT10 and sacrum most likely secondary to osteoporosis. These can\nbe followed by repeat imaging as an outpatient.\n\n\n\n                            [**First Name8 (NamePattern2) **] [**First Name4 (NamePattern1) 1775**] [**Last Name (NamePattern1) **], M.D.  [**MD Number(1) 1776**]\n\nDictated By:[**Hospital 1807**]\nMEDQUIST36\n\nD:  [**2151-8-5**]  12:11\nT:  [**2151-8-5**]  12:21\nJOB#:  [**Job Number 1808**]\n'

# %%
from transformers import AutoTokenizer, AutoModel
tokenizer = AutoTokenizer.from_pretrained("emilyalsentzer/Bio_ClinicalBERT")
model     =     AutoModel.from_pretrained("emilyalsentzer/Bio_ClinicalBERT")

embeddings = []
counter = 0
with torch.no_grad():
    for note in clin_notes:
        counter += 1
        #print("Going through note:", counter)
        inputs = tokenizer(note, return_tensors="pt", padding=True, truncation=True, max_length=512)
        outputs = model(**inputs)
        # Get the last layer's hidden states
        hidden_states = outputs.last_hidden_state
        # Get the embedding for the [CLS] token (first token)
        cls_embedding = hidden_states[:, 0, :]  # Select the first token ([CLS])
        #print(cls_embedding.squeeze().tolist())
        #print(len(cls_embedding.squeeze().tolist()))
        embeddings.append(cls_embedding.squeeze().tolist())



# Create a DataFrame containing the clinical notes and their embeddings
data = {"Clinical Note": subsampled_notes_df['ROW_ID'].tolist(), "Embedding": embeddings}


embeddings_df = pd.DataFrame(data)

# %%
print(embeddings_df.head())
# Out:
#    Clinical Note                                          Embedding
# 0            174  [0.41959381103515625, 0.12878957390785217, -0....
# 1            175  [-0.1278892457485199, -0.009227210655808449, -...
# 2            176  [-0.06606630980968475, 0.21083956956863403, -0...
# 3            177  [0.026115955784916878, 0.27625882625579834, -0...
# 4            178  [0.21620851755142212, -0.03747304901480675, -0...

# %%
random_record = embeddings_df.sample(n=1)  # This returns a DataFrame with one randomly selected row
random_record['Embedding'].tolist()
# Out:
# [[-0.10072151571512222,
#   0.23745352029800415,
#   -0.27874448895454407,
#   0.032923657447099686,
#   0.03463217616081238,
#   0.015540647320449352,
